# %%
import sys
sys.path.append("../../src")

from audio_preprocessor import AudioPreprocessor
from IPython.display import Audio, display

preprocessor = AudioPreprocessor()

original_audio,sr = preprocessor.load_audio("common_voice_en_18499990.mp3")
print("original audio")
display(Audio(original_audio, rate=sr))

processed_audio, sr = preprocessor.preprocess("common_voice_en_18499990.mp3")

print("processed audio")
display(Audio(processed_audio, rate=sr))
# Out:
# original audio
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# processed audio
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
